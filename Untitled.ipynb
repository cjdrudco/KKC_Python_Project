# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv("data.csv", encoding='cp949')

homeTeam = '맨시티'
nameDf = df[df['홈'] == homeTeam]
freeKickDf = nameDf['프리킥']
cornerKickDf = nameDf['코너킥']
setpieceDf1 = freeKickDf + cornerKickDf
scores1 = nameDf['득점']

awayTeam = '리버풀'
nameDf = df[df['원정'] == awayTeam]
freeKickDf = nameDf['프리킥']
cornerKickDf = nameDf['코너킥']
setpieceDf2 = freeKickDf + cornerKickDf
scores2 = nameDf['득점']

x1 = setpieceDf1
x2 = setpieceDf2
y1 = scores1
y2 = scores2

plt.bar(x, y1)
plt.bar(x, y2)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv("data.csv", encoding='cp949')
#       2 df
#
# NameError: name 'pd' is not defined

# %%
category = '홈'
home_df = pd.DataFrame(df[category])
home_df
# Out:
#          홈
# 0    브랜트포드
# 1       맨유
# 2       번리
# 3       첼시
# 4      에버턴
# ..     ...
# 375    팰리스
# 376   레스터
# 377    리버풀
# 378    맨시티
# 379    노리치
#
# [380 rows x 1 columns]

# %%
temp = home_df.values.tolist()
res = []
for t in temp:
    res.append(t[0])
res
# Out:
# ['브랜트포드',
#  '맨유',
#  '번리',
#  '첼시',
#  '에버턴',
#  '레스터 ',
#  '왓포드',
#  '노리치',
#  '뉴캐슬',
#  '토트넘',
#  '리버풀',
#  '아스톤빌라',
#  '팰리스',
#  '리즈',
#  '맨시티',
#  '브라이튼',
#  '사우샘스턴',
#  '울버햄튼',
#  '아스널',
#  '웨스트햄',
#  '맨시티',
#  '아스톤빌라',
#  '브라이튼',
#  '뉴캐슬',
#  '노리치',
#  '웨스트햄',
#  '리버풀',
#  '번리',
#  '토트넘',
#  '울버햄튼',
#  '팰리스',
#  '아스널',
#  '브렌트포드',
#  '레스터 ',
#  '맨유',
#  '사우샘스턴',
#  '왓포드',
#  '첼시',
#  '리즈',
#  '에버턴',
#  '뉴캐슬',
#  '울버햄튼',
#  '번리',
#  '리버풀',
#  '맨시티',
#  '노리치',
#  '아스톤 빌라',
#  '브라이튼',
#  '웨스트햄',
#  '토트넘',
#  '첼시',
#  '맨유',
#  '에버턴',
#  '리즈',
#  '레스터 ',
#  '왓포드',
#  '브렌트포드',
#  '사우샘스턴',
#  '아스널',
#  '팰리스',
#  '맨유',
#  '번리',
#  '첼시',
#  '리즈',
#  '울버햄튼',
#  '브라이튼',
#  '팰리스',
#  '토트넘',
#  '웨스트햄',
#  '리버풀',
#  '왓포드',
#  '아스톤 빌라',
#  '레스터 ',
#  '맨시티',
#  '노리치',
#  '사우샘스턴',
#  '브렌트포드',
#  '에버턴',
#  '뉴캐슬',
#  '아스널',
#  '아스널',
#  '첼시',
#  '팰리스',
#  '에버턴',
#  '리즈',
#  '사우샘스턴',
#  '브라이튼',
#  '브렌트포드',
#  '웨스트햄',
#  '맨유',
#  '레스터 ',
#  '번리',
#  '리버풀',
#  '맨시티',
#  '뉴캐슬',
#  '왓포드',
#  '토트넘',
# ...

# %%
name = '리버풀'
dfName = df[df['홈'] == name]
dfName
# Out:
#                    시간    홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  실점   \
# 10   2022-08-21 20:30  리버풀   2   0  17     9  63%    8   19      3  ...    2
# 26    2022-08-29 1:30  리버풀   1   1  14     7  65%   12    6      0  ...    1
# 43   2022-09-18 23:00  리버풀   3   0  14    10  61%   10   14      1  ...    3
# 69    2022-10-04 0:30  리버풀   2   2   3     3  48%    3   17      2  ...    2
# 92   2022-10-30 23:00  리버풀   2   2   7     3  51%    5    7      1  ...    2
# 117   2022-11-21 2:30  리버풀   4   0  13    10  66%    6   20      2  ...    4
# 122   2022-11-28 0:00  리버풀   4   0  15     6  62%    5   15      2  ...    4
# 153   2022-12-12 0:00  리버풀   1   0  18     9  63%   11    8      2  ...    1
# 164   2022-12-17 5:00  리버풀   3   1  15     7  74%   11    5      2  ...    3
# 199  2023-01-16 23:00  리버풀   3   0  16    10  68%    9   11      2  ...    3
# 223   2023-02-11 4:45  리버풀   2   0  20    12  70%    7   11      3  ...    2
# ...

# %%
ths_df = pd.DataFrame(df[['시간', '홈', '득점']])
ths_df
# Out:
#                    시간      홈  득점
# 0     2022-08-14 4:00  브랜트포드   2
# 1    2022-08-14 20:30     맨유   5
# 2    2022-08-14 23:00     번리   1
# 3    2022-08-14 23:00     첼시   3
# 4    2022-08-14 23:00    에버턴   3
# ..                ...    ...  ..
# 375   2023-05-23 0:00    팰리스   1
# 376   2023-05-23 0:00   레스터    4
# 377   2023-05-23 0:00    리버풀   3
# 378   2023-05-23 0:00    맨시티   3
# 379   2023-05-23 0:00    노리치   0
#
# [380 rows x 3 columns]

# %%
name = '첼시'
ths_df = df[df['홈'] == name]
ths_df = pd.DataFrame(df[['시간', '홈', '득점']])
# Out:
#                    시간      홈  득점
# 0     2022-08-14 4:00  브랜트포드   2
# 1    2022-08-14 20:30     맨유   5
# 2    2022-08-14 23:00     번리   1
# 3    2022-08-14 23:00     첼시   3
# 4    2022-08-14 23:00    에버턴   3
# ..                ...    ...  ..
# 375   2023-05-23 0:00    팰리스   1
# 376   2023-05-23 0:00   레스터    4
# 377   2023-05-23 0:00    리버풀   3
# 378   2023-05-23 0:00    맨시티   3
# 379   2023-05-23 0:00    노리치   0
#
# [380 rows x 3 columns]

# %%
name = '첼시'
ths_df = df[df['홈'] == name]

ths_df = pd.DataFrame(df[['시간', '홈', '득점']])
ths_dfdf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7440/938043045.py in <module>
#       3
#       4 ths_df = pd.DataFrame(df[['시간', '홈', '득점']])
# ----> 5 ths_dfdf
#
# NameError: name 'ths_dfdf' is not defined

# %%
df.sort_values(by='시간')
# Out:
#                    시간      홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  \
# 1    2022-08-14 20:30     맨유   5   1  15     9  49%    5   12      5  ...
# 2    2022-08-14 23:00     번리   1   2   9     6  45%    7    6      1  ...
# 3    2022-08-14 23:00     첼시   3   0  11     6  67%    5   12      0  ...
# 4    2022-08-14 23:00    에버턴   3   1  10     6  49%    6   15      0  ...
# 5    2022-08-14 23:00   레스터    1   0   7     7  57%    5   12      5  ...
# ..                ...    ...  ..  ..  ..   ...  ...  ...  ...    ...  ...
# 371   2023-05-23 0:00  브렌트포드   1   2  12     5  51%    3   16      0  ...
# 370   2023-05-23 0:00    아스널   5   1  17     9  74%   12    9      2  ...
# 373   2023-05-23 0:00     번리   1   2   8     5  39%    8    9      5  ...
# 379   2023-05-23 0:00    노리치   0   5   5     0  41%    3    9      0  ...
# 27             Aug-22     번리   1   1  10     4  35%    5   11      2  ...
#
#      실점   슈팅.1  유효슈팅.1 볼점유율.1  코너킥.1  프리킥.1  오프사이드.1  파울.1 경고.1  퇴장.1
# ...

# %%
df.sort_values(by='시간')
# Out:
#                    시간      홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  \
# 1    2022-08-14 20:30     맨유   5   1  15     9  49%    5   12      5  ...
# 2    2022-08-14 23:00     번리   1   2   9     6  45%    7    6      1  ...
# 3    2022-08-14 23:00     첼시   3   0  11     6  67%    5   12      0  ...
# 4    2022-08-14 23:00    에버턴   3   1  10     6  49%    6   15      0  ...
# 5    2022-08-14 23:00   레스터    1   0   7     7  57%    5   12      5  ...
# ..                ...    ...  ..  ..  ..   ...  ...  ...  ...    ...  ...
# 371   2023-05-23 0:00  브렌트포드   1   2  12     5  51%    3   16      0  ...
# 370   2023-05-23 0:00    아스널   5   1  17     9  74%   12    9      2  ...
# 373   2023-05-23 0:00     번리   1   2   8     5  39%    8    9      5  ...
# 379   2023-05-23 0:00    노리치   0   5   5     0  41%    3    9      0  ...
# 27             Aug-22     번리   1   1  10     4  35%    5   11      2  ...
#
#      실점   슈팅.1  유효슈팅.1 볼점유율.1  코너킥.1  프리킥.1  오프사이드.1  파울.1 경고.1  퇴장.1
# ...

# %%
df.sort_values(by='시간')
ths_df = pd.DataFrame(df[['시간', '홈', '득점']])
ths_df
# Out:
#                    시간      홈  득점
# 0     2022-08-14 4:00  브랜트포드   2
# 1    2022-08-14 20:30     맨유   5
# 2    2022-08-14 23:00     번리   1
# 3    2022-08-14 23:00     첼시   3
# 4    2022-08-14 23:00    에버턴   3
# ..                ...    ...  ..
# 375   2023-05-23 0:00    팰리스   1
# 376   2023-05-23 0:00   레스터    4
# 377   2023-05-23 0:00    리버풀   3
# 378   2023-05-23 0:00    맨시티   3
# 379   2023-05-23 0:00    노리치   0
#
# [380 rows x 3 columns]

# %%
name = '리버풀'
temp = ths_df[ths_df['홈'] == name]
temp
# Out:
#                    시간    홈  득점
# 10   2022-08-21 20:30  리버풀   2
# 26    2022-08-29 1:30  리버풀   1
# 43   2022-09-18 23:00  리버풀   3
# 69    2022-10-04 0:30  리버풀   2
# 92   2022-10-30 23:00  리버풀   2
# 117   2022-11-21 2:30  리버풀   4
# 122   2022-11-28 0:00  리버풀   4
# 153   2022-12-12 0:00  리버풀   1
# 164   2022-12-17 5:00  리버풀   3
# 199  2023-01-16 23:00  리버풀   3
# 223   2023-02-11 4:45  리버풀   2
# 239   2023-02-20 0:00  리버풀   3
# 246   2023-02-24 4:45  리버풀   6
# 263   2023-03-06 2:30  리버풀   1
# 288  2023-04-02 20:30  리버풀   2
# 315   2023-04-20 4:00  리버풀   4
# 329   2023-04-25 0:30  리버풀   2
# 347   2023-05-08 3:45  리버풀   1
# 377   2023-05-23 0:00  리버풀   3

# %%
score = []
temp['득점']
temp1 = pd.DataFrame(temp['득점']).values.tolist()
temp1
for t in temp1:
    score.append(t[0])

score
# Out:
# [2, 1, 3, 2, 2, 4, 4, 1, 3, 3, 2, 3, 6, 1, 2, 4, 2, 1, 3]

# %%
temp['득점'].mean()
# Out:
# 2.5789473684210527

# %%
x = temp['시간']
y = temp['득점']
plt.plot(x, y)
plt.show()

# %%
dfName['실점'].mean()
# Out:
# 1.1578947368421053

# %%
dfName['슈팅'].mean()
# Out:
# 11.263157894736842

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
score = df['득점']
name = df[df['홈'] == teamName]
teamScore = name['득점']
time = name['시간']
x = time
y = teamScore
plt.plot(x, y)
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
name = df[df['홈'] == teamName]
teamLoss = name['실점']
time = name['시간']
x = time
y = teamLoss
plt.plot(x, y)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
name = df[df['홈'] == teamName]
shoot = df['유효슈팅']
teamShoot = name['유효슈팅']
teamScore = name['득점']
x = teamShoot
y = teamScore
plt.bar(x, y)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
teamAway = df[df['원정'] == teamName]
teamHome = df[df['홈'] == teamName]
final = pd.concat([teamAway, teamHome])
res = final.sort_values(by='시간')

res.head(3)
# Out:
#                   시간    홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  실점   \
# 9    2022-08-16 0:30  토트넘   1   0   6     2  35%    3    9      3  ...    1
# 14  2022-08-21 23:00  맨시티   5   0  11     5  65%    6   10      2  ...    5
# 20  2022-08-28 20:30  맨시티   5   0  14    11  81%   14   10      1  ...    5
#
#     슈팅.1  유효슈팅.1 볼점유율.1  코너킥.1  프리킥.1  오프사이드.1  파울.1 경고.1  퇴장.1
# 9     11       3    65%     11     14        1     8    1     0
# 14     1       0    35%      1     15        3     7    0     0
# 20     1       0    19%      0      6        3     7    2     1
#
# [3 rows x 25 columns]

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
topThreeDf = df[df['홈'] == teamName].head(3)
# topThreeDf
# d = {
#     '시간': topThreeDf['시간'].values.tolist(),
#     '홈' : topThreeDf['홈'].values.tolist()
# }

res = []
cols = ['시간', '홈', '득점']
for i in range(3):
    d = {}
    for col in cols:
        d[col] = topThreeDf[col].values.tolist()[i]
    res.append(d)
res
# Out:
# [{'시간': '2022-08-21 23:00', '홈': '맨시티', '득점': 5},
#  {'시간': '2022-08-28 20:30', '홈': '맨시티', '득점': 5},
#  {'시간': '2022-09-18 23:00', '홈': '맨시티', '득점': 0}]

# %%
df = pd.read_csv("data.csv", encoding='cp949')

homeTeam = '맨시티'
awayTeam = '리버풀'

temp = df[df['홈'] == homeTeam]
temp = temp[temp['원정'] == awayTeam]

temp
# Out:
#                   시간    홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  실점   \
# 308  2023-04-11 0:30  맨시티   2   2   9     4  56%    4   13      5  ...    2
#
#      슈팅.1  유효슈팅.1 볼점유율.1  코너킥.1  프리킥.1  오프사이드.1  파울.1 경고.1  퇴장.1
# 308     4       4    44%      1     14        2    11    4     0
#
# [1 rows x 25 columns]

# %%
df = pd.read_csv("data.csv", encoding='cp949')

homeTeam = '리버풀'
awayTeam = '맨시티'

temp = df[df['홈'] == homeTeam]
temp = temp[temp['원정'] == awayTeam]

temp
# Out:
#                  시간    홈  득점  실점  슈팅  유효슈팅 볼점유율  코너킥  프리킥  오프사이드  ...  실점   \
# 69  2022-10-04 0:30  리버풀   2   2   3     3  48%    3   17      2  ...    2
#
#     슈팅.1  유효슈팅.1 볼점유율.1  코너킥.1  프리킥.1  오프사이드.1  파울.1 경고.1  퇴장.1
# 69     6       3    52%      4     12        5    12    3     0
#
# [1 rows x 25 columns]

# %%
teamName = '맨시티'
name = df[df['홈'] == teamName]
score = name['득점']
name['득점'].mean()
# Out:
# 3.0526315789473686

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("data.csv", encoding='cp949')

# %%
# 득점 분석 꺾은선 그래프

df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
name = df[df['홈'] == teamName]
teamScore = name['득점']
time = name['시간']
x = time
y = teamScore
plt.plot(x, y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # 득점 분석 꺾은선 그래프
# ----> 3 df = pd.read_csv("data.csv", encoding='cp949')
#       5 teamName = '맨시티'
#       6 name = df[df['홈'] == teamName]
#
# NameError: name 'pd' is not defined

# %%
# 실점 분석 꺾은선 그래프

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '리버풀'
name = df[df['원정'] == teamName]
teamScore = name['득점']
time = name['시간']
x = time
y = teamScore
plt.plot(x, y)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')

homeTeam = '맨시티'
name = df[df['홈'] == teamName]
teamScore1= name['득점']
time = name['시간']

awayTeam = '리버풀'
name = df[df['원정'] == awayTeam]
teamScore2= name['득점']


x = time
y1 = teamScore1
y2 = teamScore2

plt.plot(x, y1)
plt.plot(x, y2)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')

homeTeam = '맨시티'
name = df[df['홈'] == homeTeam]
res = 0

if '득점' > '실점' : 
    res = '승'
else : 
    res = '패'

res
# Out:
# '패'

# %%
homeTeam = '맨시티'
home = df[df['홈'] == homeTeam]

gain = home['득점'].values.tolist()
loss = home['실점'].values.tolist()

count = 0
for i in range(len(gain)):
    if gain[i] > loss[i]:
        count += 1

        
awayTeam = '리버풀'
away = df[df['원정'] == awayTeam]

gain = home['득점'].values.tolist()
loss = home['실점'].values.tolist()

count2 = 0
for i in range(len(gain)):
    if gain[i] > loss[i]:
        count2 += 1
        
x1 = homeTeam
x2 = awayTeam

y1 = count
y2 = count2

plt.bar(x1, y1)
plt.bar(x2, y2)
plt.show()
# Out:
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47592 (\N{HANGUL SYLLABLE MAEN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49884 (\N{HANGUL SYLLABLE SI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54000 (\N{HANGUL SYLLABLE TI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 47532 (\N{HANGUL SYLLABLE RI}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\ProgramData\anaconda3\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 48260 (\N{HANGUL SYLLABLE BEO}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
homeTeam
# Out:
# '맨시티'

# %%
awayTeam = '리버풀'
away = df[df['원정'] == awayTeam]

gain = home['득점'].values.tolist()
loss = home['실점'].values.tolist()

count2 = 0
for i in range(len(gain)):
    if gain[i] > loss[i]:
        count2 += 1
        
count2
# Out:
# 15

# %%
k = df['볼점유율'].values.tolist()
t = []
for item in k:
    t.append(int(item.replace('%', '')))

# %%
avg = sum(t) / len(t)
avg
# Out:
# 50.57368421052632

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
team = df[df['홈'] == teamName]

k = team['볼점유율'].values.tolist()
t = []
for item in k:
    t.append(int(item.replace('%', '')))
    
avg = sum(t) / len(t)
avg
# Out:
# 66.05263157894737

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '리버풀'
team = df[df['원정'] == teamName]

k = team['볼점유율'].values.tolist()
t = []
for item in k:
    t.append(int(item.replace('%', '')))
    
avg = sum(t) / len(t)
avg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = pd.read_csv("data.csv", encoding='cp949')
#       3 teamName = '리버풀'
#       4 team = df[df['원정'] == teamName]
#
# NameError: name 'pd' is not defined

# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv("data.csv", encoding='cp949')

teamName= '맨시티'
team = df[df['홈'] == teamName]

share = team['볼점유율']
score = team['득점']

plt.scatter(share, score)
plt.show()

# %%
df = pd.read_csv("data.csv", encoding='cp949')

teamName = '리버풀'
team = df[df['원정'] == teamName]

share = team['볼점유율']
score = team['득점']

plt.scatter(share, score)
plt.show()

# %%
from matplotlib import pyplot as plt
import pandas as pd

df = pd.read_csv("data.csv", encoding='cp949')

df = pd.read_csv("data.csv", encoding='cp949')

teamName = '맨시티'
team = df[df['홈'] == teamName]

k = team['볼점유율'].values.tolist()
t = []
for item in k:
    t.append(int(item.replace('%', '')))
    
avg = round(sum(t) / len(t))
avg
# Out:
# 66

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


df_origin = pd.read_csv("lotte_csv.csv", encoding="EUC_KR")
df = df_origin[df_origin['OP'] == 'SK']

train_year = (df["YEAR"] <= 2018)
test_year = (df["YEAR"] >= 2019)
interval = 5

def make_data(data):
    x_r = []
    y_r = []
    x_er = []
    y_er = []

    r = list(data["R"])
    er = list(data["ER"])
    for i in range(len(r)):
        if i < interval : continue
        elif data.iloc[i, 0] != data.iloc[i-1, 0] : continue
        y_r.append(r[i])
        y_er.append(er[i])

        xa = []
        xb = []
        for p in range(interval):
            d = i + p - interval
            xa.append(r[d])
            xb.append(er[d])
        x_r.append(xa)
        x_er.append(xb)
    return (x_r, y_r, x_er, y_er)
train_x_r , train_y_r, train_x_er, train_y_er = make_data(df[train_year])
test_x_r, test_y_r, test_x_er, test_y_er = make_data(df[test_year])


model1 = RandomForestClassifier()
model2 = RandomForestClassifier()
model1.fit(train_x_r, train_y_r)
model2.fit(train_x_er, train_y_er)

pre_y_r = model1.predict(test_x_r)
pre_y_er = model2.predict(test_x_er)

diff_y_r = abs(pre_y_r-test_y_r)
diff_y_er = abs(pre_y_er-test_y_er)
a = [x for x in diff_y_r if x <= 2]
b = [x for x in diff_y_er if x <= 2]
print("average_r =", sum(diff_y_r)/len(diff_y_r), "max_r =", max(diff_y_r), "score =", len(a)/len(diff_y_r)*100)
print("average_er =", sum(diff_y_er)/len(diff_y_er), "max_er =", max(diff_y_er), "score =", len(b)/len(diff_y_er)*100)

wdl = []
for i in range(len(pre_y_r)):
    if abs(pre_y_r[i]-pre_y_er[i]) == 0 :
        wdl.append("무")
    elif pre_y_r[i] > pre_y_er[i] :
        wdl.append("승")
    else :
        wdl.append("패")

data = df[test_year]
test_wdl = list(data["WDL"])
y = 0
for i in range(len(wdl)):
    if wdl[i] == test_wdl[i]:
        y += 1

print("승패 정확도 :", y/len(wdl)*100)


plt.subplot(2, 1, 1)
plt.plot(test_y_r, c='r')
plt.plot(pre_y_r, c='b')

plt.subplot(2,1,2)
plt.plot(test_y_er, c='r')
plt.plot(pre_y_er, c='b')
plt.show()
# Out:
# average_r = 4.2727272727272725 max_r = 10 score = 36.36363636363637
# average_er = 2.272727272727273 max_er = 6 score = 45.45454545454545
# 승패 정확도 : 27.27272727272727

# %%
from sklearn.ensemble import RandomForestClassifier
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


df = pd.read_csv("data.csv", encoding="cp949")


train_year = (df["시간"] <= df.iloc[0,0])
test_year = (df["시간"] >= df.iloc[379,0])
interval = 5


def make_data(data):
    x_s = []
    y_s = []
    x_l = []
    y_l = []
    
    score = list(data['득점'])
    loss = list(data['실점'])
    
    for i in range(len(score)) : 
        if i < interval : continue 
        elif data.iloc[i, 0] != data.iloc[i-1, 0] : continue
        y_s.append(score[i])
        y_l.append(loss[i])
        
        xa = []
        xb = []
        for p in range(interval):
            d = i + p - interval
            xa.append(score[d])
            xb.append(loss[d])
        x_s.append(xa)
        x_l.append(xb)
    return (x_s, y_s, x_l, y_l)
train_x_s , train_y_s, train_x_l, train_y_l = make_data(df[train_year])
test_x_s, test_y_s, test_x_l, test_y_l = make_data(df[test_year])


model1 = RandomForestClassifier()
model2 = RandomForestClassifier()
model1.fit(train_x_s, train_y_s)
model2.fit(train_x_l, train_y_l)

pre_y_s = model1.predict(test_x_s)
pre_y_l = model2.predict(test_x_l)

diff_y_s = abs(pre_y_s-test_y_s)
diff_y_l = abs(pre_y_l-test_y_l)
a = [x for x in diff_y_s if x <= 2]
b = [x for x in diff_y_l if x <= 2]
print("average_s =", sum(diff_y_s)/len(diff_y_s), "max_r =", max(diff_y_s), "score =", len(a)/len(diff_y_s)*100)
print("average_l =", sum(diff_y_l)/len(diff_y_l), "max_l =", max(diff_y_l), "score =", len(b)/len(diff_y_l)*100)

wdl = []
for i in range(len(pre_y_s)):
    if abs(pre_y_s[i]-pre_y_l[i]) == 0 :
        wdl.append("무")
    elif pre_y_s[i] > pre_y_l[i] :
        wdl.append("승")
    else :
        wdl.append("패")

data = df[test_year]
test_wdl = list(data["WDL"])
y = 0
for i in range(len(wdl)):
    if wdl[i] == test_wdl[i]:
        y += 1

print("승패 정확도 :", y/len(wdl)*100)


plt.subplot(2, 1, 1)
plt.plot(test_y_s, c='r')
plt.plot(pre_y_s, c='b')

plt.subplot(2,1,2)
plt.plot(test_y_l, c='r')
plt.plot(pre_y_l, c='b')
plt.show()
# Out:
# average_s = 2.1666666666666665 max_r = 3 score = 66.66666666666666
# average_l = 1.3333333333333333 max_l = 3 score = 83.33333333333334
# 승패 정확도 : 0.0
